# %%
import cv2
import numpy as np
import random

img = cv2.imread('messi5.jpg',0)
rows,cols = img.shape

axis_offset = random.uniform(-2,2)
angle = random.uniform(-15,15)
scale = random.uniform(0.95,1.05)

M = cv2.getRotationMatrix2D((cols/2 + axis_offset,rows/2 + axis_offset),angle,scale)
dst = cv2.warpAffine(img,M,(cols,rows))

# %%
rows,cols = img.shape
off = 50

x_pt1 = np.array([cols/2, cols/4, 3*cols/4])
y_pt1 = np.array([rows/4, 3*rows/4, 3*rows/4])
x_offset = (np.random.rand(3) - 0.5) * off
y_offset = (np.random.rand(3) - 0.5) * off
x_pt2 = x_pt1 + x_offset
y_pt2 = y_pt1 + y_offset

pt1 = list(map(list, zip(*np.vstack((x_pt1, y_pt1)))))
pt2 = list(map(list, zip(*np.vstack((x_pt2, y_pt2)))))
pts1 = np.float32(pt1)
pts2 = np.float32(pt2)

M = cv2.getAffineTransform(pts1,pts2)
dst = cv2.warpAffine(img,M,(cols,rows))

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

plt.imshow(img, cmap='gray')
plt.show()
# plt.plot(x_pt1, y_pt1,'red')
# plt.figure()
# plt.plot(x_pt2, y_pt2, 'red')
# plt.figure()
plt.imshow(dst, cmap='gray')
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('messi5.jpg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
cdf_m = np.ma.masked_equal(cdf,0)
cdf_m = (cdf_m - cdf_m.min())*255/(cdf_m.max()-cdf_m.min())
cdf = np.ma.filled(cdf_m,0).astype('uint8')
img2 = cdf[img]

# %%
img = cv2.imread('messi5.jpg',0)
equ = cv2.equalizeHist(img)
res = np.hstack((img,equ)) #stacking images side-by-side
cv2.imwrite('res.png',res)
# Out:
# True

# %%
img = cv2.imread('messi5.jpg',0) #load rgb image
img += 10

# %%
plt.imshow(img, cmap='gray')
plt.show()

# %%
img = cv2.imread('lena.jpg',0) #load rgb image
rows,cols = img.shape
off = 50

x_pt1 = np.array([0, cols, 0, cols])
y_pt1 = np.array([0, 0, rows, rows])
x_offset = (np.random.rand(4) - 0.5) * off
y_offset = (np.random.rand(4) - 0.5) * off
x_pt2 = x_pt1 + x_offset
y_pt2 = y_pt1 + y_offset

pt1 = list(map(list, zip(*np.vstack((x_pt1, y_pt1)))))
pt2 = list(map(list, zip(*np.vstack((x_pt2, y_pt2)))))
pts1 = np.float32(pt1)
pts2 = np.float32(pt2)
print(pts1)
print(pts2)

M = cv2.getPerspectiveTransform(pts1,pts2)

dst = cv2.warpPerspective(img,M,(512,512))

# plt.subplot(121),plt.imshow(img),plt.title('Input')
# plt.subplot(122),plt.imshow(dst),plt.title('Output')
# plt.show()
# Out:
# [[   0.    0.]
#  [ 512.    0.]
#  [   0.  512.]
#  [ 512.  512.]]
# [[   2.74249911    8.18563652]
#  [ 504.67300415   23.59995461]
#  [  12.36532497  497.25564575]
#  [ 514.00030518  505.87942505]]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# plt.imshow(img, cmap='gray')
# plt.show()
# plt.plot(x_pt1, y_pt1,'red')
# plt.figure()
# plt.plot(x_pt2, y_pt2, 'red')
# plt.figure()
plt.imshow(dst, cmap='gray')
plt.show()

# %%
dst = cv2.equalizeHist(img)

# %%
plt.imshow(dst, cmap='gray')
